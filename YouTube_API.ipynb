# %%
import os
import re
from datetime import timedelta
from googleapiclient.discovery import build

# %%
api_key = 'AIzaSyCZAFRXieTTrY5K17MkAiE9EQK4j40mwDc'

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
pl_request = youtube.playlistItems().list(
part = 'contentDetails',
playlistId = "PL5uULy4b0kV4jgvU67mrIxvJgmnqKcgfa",
maxResults = 50)

pl_response = pl_request.execute()

pl_response
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'mt6UgCmPaQ3QclQZ7WBrGzxIku0',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'Jq5JGT0vcIMYRco0I1aWzTmYO0s',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS4yMUQyQTQzMjRDNzMyQTMy',
#    'contentDetails': {'videoId': 'AYvOSrgvCrk',
#     'videoPublishedAt': '2012-04-24T01:07:47Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'pmBPGZECfSSAByuouaHzyjmqad8',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS41MzJCQjBCNDIyRkJDN0VD',
#    'contentDetails': {'videoId': 'IR9Av-TzSV4',
#     'videoPublishedAt': '2011-06-10T19:46:57Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'QzakSfGVNixxt3cM791w8_hRDGI',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS42MTI4Njc2QjM1RjU1MjlG',
#    'contentDetails': {'videoId': 'QHfWv1QAzE8',
#     'videoPublishedAt': '2010-01-12T14:47:21Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'IbtCq7wxWQkMJKeY7uO7fscqGX0',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS40NzZCMERDMjVEN0RFRThB',
#    'contentDetails': {'videoId': 'SXEXX8bkLDI',
#     'videoPublishedAt': '2011-06-14T19:57:35Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '5hkYtLX0HtYgYBVcvOaFIrsJybg',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS41NkI0NEY2RDEwNTU3Q0M2',
#    'contentDetails': {'videoId': 'eutYWr53mFE',
#     'videoPublishedAt': '2011-05-31T20:09:32Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'kPDzk4ievHYcMQ27E13T-yfYFb0',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS41MjE1MkI0OTQ2QzJGNzNG',
#    'contentDetails': {'videoId': 'g5qaujLIfZE',
#     'videoPublishedAt': '2012-04-24T00:32:08Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'HrtZolCwkGMkpAb3kdTTGmkq-Sc',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS4xMkVGQjNCMUM1N0RFNEUx',
#    'contentDetails': {'videoId': 'qaDDKHFg3Tg',
#     'videoPublishedAt': '2012-04-24T00:41:21Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'J-vfoGEVnrw_cHiTXXCx1IfDkd0',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS45NzUwQkI1M0UxNThBMkU0',
#    'contentDetails': {'videoId': 'ZKqk2nDJqOA',
#     'videoPublishedAt': '2012-04-24T01:08:45Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '6v3_wP5cgy0hJBeshrh8fBszIIM',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS4zQzFBN0RGNzNFREFCMjBE',
#    'contentDetails': {'videoId': 'v0KB130rVko',
#     'videoPublishedAt': '2019-11-23T13:33:43Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'uR3jUyzkZ5s6N7wdWIqUPjdSEdo',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS4yMDhBMkNBNjRDMjQxQTg1',
#    'contentDetails': {'videoId': 'gxHkjX0ZDlA',
#     'videoPublishedAt': '2012-04-24T01:06:50Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Bp0KyC7N7Mwqm2NyrFejCLTsGvQ',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS4wMTcyMDhGQUE4NTIzM0Y5',
#    'contentDetails': {'videoId': 'RKlMJM3NYOU',
#     'videoPublishedAt': '2012-04-24T00:41:17Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'YgO67_OU7_PKqcsRsX0oVkeqEWc',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS41QTY1Q0UxMTVCODczNThE',
#    'contentDetails': {'videoId': 'Eam45lydzco',
#     'videoPublishedAt': '2012-04-24T01:46:15Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag':
z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '5xa_S0zZrCaCcOjO28-puohehFU',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS5CMEQ2Mjk5NTc3NDZFRUNB',
#    'contentDetails': {'videoId': 'mge6qe_U1Ow',
#     'videoPublishedAt': '2012-04-24T01:46:10Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'e1a669hpuArVA3Kynx5cLNFhQrE',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS5GM0Q3M0MzMzY5NTJFNTdE',
#    'contentDetails': {'videoId': '8_w_7442mC0',
#     'videoPublishedAt': '2011-05-20T20:39:26Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'seQvQHlhShIw1ag3Pr94N_yzX_s',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS4zMDg5MkQ5MEVDMEM1NTg2',
#    'contentDetails': {'videoId': 'x3ScGOYQYEI',
#     'videoPublishedAt': '2012-04-24T01:46:13Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'd7EG7f0eCtz_kN8XwX4ZVlrv6ss',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS45RTgxNDRBMzUwRjQ0MDhC',
#    'contentDetails': {'videoId': 'RRqBds8B3Mk',
#     'videoPublishedAt': '2012-04-24T00:53:05Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'HtM2j7CpX3nM6pPuV-lmFedJbO8',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS5DNkMwRUI2MkI4QkI4NDFG',
#    'contentDetails': {'videoId': 'of4_TrpGrX0',
#     'videoPublishedAt': '2016-08-10T17:21:07Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'TGZNFHYq7fYsdA18A9EFcfnICk0',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS4xOTEzQzhBQzU3MDNDNjcz',
#    'contentDetails': {'videoId': 'V1JyZkLbrwg',
#     'videoPublishedAt': '2016-05-05T17:00:02Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'LFs1D2DUsGr9f_c51lQps3itAM8',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS5GNDg1Njc1QzZERjlFRjE5',
#    'contentDetails': {'videoId': 'OE-t-tyTiD8',
#     'videoPublishedAt': '2017-09-25T17:47:28Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'YfNZzsuswrfC9dLkS7Z1kVugu7k',
#    'id': 'UEw1dVVMeTRiMGtWNGpndlU2N21ySXh2SmdtbnFLY2dmYS45RjNFMDhGQ0Q2RkFCQTc1',
#    'contentDetails': {'videoId': 'm2VXyBOmK3Q',
#     'videoPublishedAt': '2019-11-02T09:50:56Z'}}],
#  'pageInfo': {'totalResults': 34, 'resultsPerPage': 50}}

# %%
vid_ids = []
for item in pl_response['items']:
    vid_ids.append(item['contentDetails']['videoId'])

# %%
print(vid_ids)
# Out:
# ['AYvOSrgvCrk', 'IR9Av-TzSV4', 'QHfWv1QAzE8', 'SXEXX8bkLDI', 'eutYWr53mFE', 'g5qaujLIfZE', 'qaDDKHFg3Tg', 'ZKqk2nDJqOA', 'v0KB130rVko', 'gxHkjX0ZDlA', 'RKlMJM3NYOU', 'Eam45lydzco', 'z1_TYVUtEqM', '4uvmh2g6jYk', 'pTOjkwkeEF0', 'u4yhWRVC6jU', 'votk_vhBrAs', 'cBmRiJCxCnw', 'kiAv9Ztd5TE', 'ZIOskOVNSQI', 'UnWIsWoUQuk', 'nIfAKq_yKLk', 'pvR22af3JvQ', 'i9KGUPk-Jn4', 'REe629FoW_4', 'k9Tt4dXcglc', 'mge6qe_U1Ow', '8_w_7442mC0', 'x3ScGOYQYEI', 'RRqBds8B3Mk', 'of4_TrpGrX0', 'V1JyZkLbrwg', 'OE-t-tyTiD8', 'm2VXyBOmK3Q']

# %%
vid_request = youtube.videos().list(
part = "contentDetails",
id=','.join(vid_ids))

vid_response = vid_request.execute()

vid_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'Gma0GdQB4KkbcYg1Srk92cVGrWw',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'Zbk8G5Gmg2PSVk8XwtBvgcAeltI',
#    'id': 'AYvOSrgvCrk',
#    'contentDetails': {'duration': 'PT1M20S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'KESWABD9EiVBfs0eIs8Hwe5YwFA',
#    'id': 'IR9Av-TzSV4',
#    'contentDetails': {'duration': 'PT5M47S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '6gxJolOKLvHPLIdoQVUDwYSy8cE',
#    'id': 'QHfWv1QAzE8',
#    'contentDetails': {'duration': 'PT2M24S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'GDw730aaef5O3KytYdssJ0s20Lk',
#    'id': 'SXEXX8bkLDI',
#    'contentDetails': {'duration': 'PT4M57S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'RLy0bs7aNuIWmAcaqGVnX25EnK4',
#    'id': 'eutYWr53mFE',
#    'contentDetails': {'duration': 'PT3M14S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'My3YZvNqCSCZOKTv846AvBamLtQ',
#    'id': 'g5qaujLIfZE',
#    'contentDetails': {'duration': 'PT3M51S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'IZLuCYi8JAvNcuoAaUvT0eaV-Ew',
#    'id': 'qaDDKHFg3Tg',
#    'contentDetails': {'duration': 'PT6M45S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'VMmYUlxfwCuXNxPpdVDQstgK664',
#    'id': 'ZKqk2nDJqOA',
#    'contentDetails': {'duration': 'PT10M1S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'qfXiDfwq4ecrUZjjx_lbl6y3VTE',
#    'id': 'v0KB130rVko',
#    'contentDetails': {'duration': 'PT2M',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'O1J7ZTmvRbjHCXS-HfRK0gCaELM',
#    'id': 'gxHkjX0ZDlA',
#    'contentDetails': {'duration': 'PT3M2S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'R-9YTnZNMU43v0z7TeK8y1untUY',
#    'id': 'RKlMJM3NYOU',
#    'contentDetails': {'duration': 'PT4M55S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'XSs28TPC-ORLhm9rreJknKKRstw',
#    'id': 'Eam45lydzco',
#    'contentDetails': {'duration': 'PT4M1S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '3mK0e2t7VNFQMcCqDBrr7udHsPE',
#    'id': 'z1_TYVUtEqM',
#    'contentDetails': {'duration': 'PT7M10S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '60jV9p5z9_Uoj2qPKGCGuT-UEH0',
#    'id': '4uvmh2g6jYk',
#    'contentDetails': {'duration': 'PT2M8S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'o6uPULR3AL5XJwgwvk896iixDRI',
#    'id': 'pTOjkwkeEF0',
#    'contentDetails': {'duration': 'PT3M30S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'GnS3rrXcVcKE4JdEM2FF3gQMfYY',
#    'id': 'u4yhWRVC6jU',
#    'contentDetails': {'duration': 'PT3M48S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '7oG7hjBFNBgSs5qYUVbHhiRYNg4',
#    'id': 'votk_vhBrAs',
#    'contentDetails': {'duration': 'PT2M28S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '7oIUj63FceIzjenqChuvNoSx_Bk',
#    'id': 'cBmRiJCxCnw',
#    'contentDetails': {'duration': 'PT9M11S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'GFBhinsApSjNDSSc8yJ17L_I4p0',
#    'id': 'kiAv9Ztd5TE',
#    'contentDetails': {'duration': 'PT4M25S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '9wDRI533R6FcVhxNM43ZlDaDOoM',
#    'id': 'ZIOskOVNSQI',
#    'contentDetails': {'duration': 'PT4M21S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'SwevZnaaOpMwvnhLng68LM5KW8Q',
#    'id': 'UnWIsWoUQuk',
#    'contentDetails': {'duration': 'PT5M48S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'L76kp2z6iUj0UAX2z6vP_07q2g4',
#    'id': 'nIfAKq_yKLk',
#    'contentDetails': {'duration': 'PT4M10S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'iRP70sGloIQJUfoUJcfHZDiwswk',
#    'id': 'pvR22af3JvQ',
#    'contentDetails': {'duration': 'PT5M36S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'jAtiiRhYlRBvZeC505Ob5tRc2Mc',
#    'id': 'i9KGUPk-Jn4',
#    'contentDetails': {'duration': 'PT3M15S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '39iN2C7RtbnAT5q3evLJlkxg-8Y',
#    'id': 'REe629FoW_4',
#    'contentDetails': {'duration': 'PT8M23S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'IH1vJuZ2Ft7q2vFBGHEp1EEzv-I',
#    'id': 'k9Tt4dXcglc',
#    'contentDetails': {'duration': 'PT1M59S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '-wPfq9MyALFP2GfplKZ5HlKxo7I',
#    'id': 'mge6qe_U1Ow',
#    'contentDetails': {'duration': 'PT5M16S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '4yBPJHAMKNYZhv1yOBGf6R8SsIU',
#    'id': '8_w_7442mC0',
#    'contentDetails': {'duration': 'PT4M37S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'vdWBFON_9EYli2O8uUz1xVekI00',
#    'id': 'x3ScGOYQYEI',
#    'contentDetails': {'duration': 'PT12M55S',
#     'dimension': '2d',
#     'definition': 'sd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': '2O-Jzu5rTDN0rqUgIaEctXnphhA',
#    'id': 'RRqBds8B3Mk',
#    'contentDetails': {'duration': 'PT4M2S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'hTS-YnSbFTohIGvC4iPKMcBAFV8',
#    'id': 'of4_TrpGrX0',
#    'contentDetails': {'duration': 'PT5M25S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'UqzLBby4Vn3uy2izwZ4jB3S6crE',
#    'id': 'V1JyZkLbrwg',
#    'contentDetails': {'duration': 'PT4M46S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'qnaUfbCAd23yOSTw3gXbDjdj4ZU',
#    'id': 'OE-t-tyTiD8',
#    'contentDetails': {'duration': 'PT10M28S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}},
#   {'kind': 'youtube#video',
#    'etag': 'vAVlXHqsk0R3PHqAryLrR8Ubo0g',
#    'id': 'm2VXyBOmK3Q',
#    'contentDetails': {'duration': 'PT8M28S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'}}],
#  'pageInfo': {'totalResults': 34, 'resultsPerPage': 34}}

# %%
hours_pattern = re.compile(r'(\d+)H')
minutes_pattern = re.compile(r'(\d+)M')
seconds_pattern = re.compile(r'(\d+)S')

total_seconds = 0

for item in vid_response['items']:
        duration = item['contentDetails']['duration']
        
        hours = hours_pattern.search(duration)
        minutes = minutes_pattern.search(duration)
        seconds = seconds_pattern.search(duration)

        hours = int(hours.group(1)) if hours else 0
        minutes = int(minutes.group(1)) if minutes else 0
        seconds = int(seconds.group(1)) if seconds else 0

        video_seconds = timedelta(
            hours=hours,
            minutes=minutes,
            seconds=seconds
        ).total_seconds()

        total_seconds += video_seconds

# %%
total_seconds
# Out:
# 10466.0

# %%
total_seconds = int(total_seconds)

minutes, seconds = divmod(total_seconds, 60)
hours, minutes = divmod(minutes, 60)

print(f'Total running time of the playlist is: {hours}:{minutes}:{seconds}')
# Out:
# Total running time of the playlist is: 2:54:26
